# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd "/content/drive/MyDrive/Colab Notebooks/OnCampus/LongCovid/regression/Data"
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/Colab Notebooks/OnCampus/LongCovid/regression/Data

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import os

# %%
#RUNNING IN JUPYTER
os.chdir("C:\\Users\\rarsi\\Rutgers University\\Michelle Chen - COVID_Fatigue\\RC_award\\Data\\Concatenated_Data\\HRV_features")
#os.chdir("C:\\Users\\katgm\\Rutgers University\\Michelle Chen - Rutgers_Neuropsych_Lab\\COVID_Fatigue\\RC_award\\Data\\Concatenated_Data\\Padasip_Clean_Data")

# %%
f_path = "HRV_features_30seconds.xlsx"
og_data = pd.read_excel(f_path, header=0)
og_data.head()
# Out:
#    Block  fatigue_rating  window_num_30 SubjID  HRV_MeanNN    HRV_SDNN  \
# 0      0              73              0   Cov4  696.800595  117.336517
# 1      0              73              1   Cov4  725.609756  126.362148
# 2      0              73              2   Cov4  801.649306  111.729719
# 3      0              73              3   Cov4  764.802632   66.683010
# 4      0              73              4   Cov4  711.509146  106.725588
#
#    HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  ...  HRV_SampEn  \
# 0         NaN         NaN         NaN         NaN  ...    1.945910
# 1         NaN         NaN         NaN         NaN  ...    1.280934
# 2         NaN         NaN         NaN         NaN  ...    2.397895
# 3         NaN         NaN         NaN         NaN  ...    1.791759
# 4         NaN         NaN         NaN         NaN  ...    2.079442
#
#    HRV_ShanEn  HRV_FuzzyEn  HRV_MSEn  HRV_CMSEn  HRV_RCMSEn    HRV_CD  \
# ...

# %%
copy = og_data
copy['Delta_fatigue'] = pd.Series()
copy['Change_from_Baseline'] = pd.Series()
# Out:
# <ipython-input-6-7b87fa76f860>:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   copy['Delta_fatigue'] = pd.Series()

# %%
candidates = og_data['SubjID'].unique()
for candidate in candidates:
  print(candidate)
  can_df = og_data.loc[og_data['SubjID'] == candidate]
  blocks = can_df['Block'].unique()
  prev = -1
  for block in blocks:
    print(block)
    block_df = can_df.loc[can_df['Block'] == block]
    fatigue_rating = block_df['fatigue_rating'].unique()[0]
    if block == 0:
      baseline = fatigue_rating
    if prev != -1:
      delta = fatigue_rating - prev
      baseline_shift = fatigue_rating - baseline
    else:
      delta = -1
      baseline_shift = -1
    prev = fatigue_rating
    mask = (copy['SubjID'] == candidate) & (copy['Block'] == block)
    copy.loc[mask, 'Delta_fatigue'] = delta
    copy.loc[mask, 'Change_from_Baseline'] = baseline_shift

copy.to_excel("HRV_features_30seconds_withDelta.xlsx")
# Out:
# Cov4
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov5
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov7
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov8
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov13
# 0
# 6
# Cov14
# 0
# 1
# 2
# 4
# 5
# Cov19
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov20
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov23
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
f_path = "HRV_features_60seconds.xlsx"
og_data = pd.read_excel(f_path, header=0)
og_data.head()
# Out:
#    Block  fatigue_rating  window_num_60 SubjID  HRV_MeanNN    HRV_SDNN  \
# 0      0              73              0   Cov4  709.821429  121.764550
# 1      0              73              1   Cov4  783.125000   92.079715
# 2      0              73              2   Cov4  767.248377  132.329919
# 3      0              73              3   Cov4  760.416667  111.418943
# 4      0              73              4   Cov4  762.419872  109.225866
#
#    HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  ...  HRV_SampEn  \
# 0         NaN         NaN         NaN         NaN  ...    1.400893
# 1         NaN         NaN         NaN         NaN  ...    1.324925
# 2         NaN         NaN         NaN         NaN  ...    2.639057
# 3         NaN         NaN         NaN         NaN  ...    1.572397
# 4         NaN         NaN         NaN         NaN  ...    1.417066
#
#    HRV_ShanEn  HRV_FuzzyEn  HRV_MSEn  HRV_CMSEn  HRV_RCMSEn    HRV_CD  \
# ...

# %%
copy = og_data
copy['Delta_fatigue'] = pd.Series()
copy['Change_from_Baseline'] = pd.Series()
# Out:
# <ipython-input-17-8e7495bb3953>:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   copy['Delta_fatigue'] = pd.Series()
# <ipython-input-17-8e7495bb3953>:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   copy['Change_from_Baseline'] = pd.Series()

# %%
candidates = og_data['SubjID'].unique()
for candidate in candidates:
  print(candidate)
  can_df = og_data.loc[og_data['SubjID'] == candidate]
  blocks = can_df['Block'].unique()
  prev = -1
  for block in blocks:
    print(block)
    block_df = can_df.loc[can_df['Block'] == block]
    fatigue_rating = block_df['fatigue_rating'].unique()[0]
    if block == 0:
      baseline = fatigue_rating
    if prev != -1:
      delta = fatigue_rating - prev
      baseline_shift = fatigue_rating - baseline
    else:
      delta = -1
      baseline_shift = -1
    prev = fatigue_rating
    mask = (copy['SubjID'] == candidate) & (copy['Block'] == block)
    copy.loc[mask, 'Delta_fatigue'] = delta
    copy.loc[mask, 'Change_from_Baseline'] = baseline_shift

copy.to_excel("HRV_features_60seconds_withDelta.xlsx")
# Out:
# Cov4
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov5
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov7
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov8
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov13
# 0
# 5
# 6
# Cov14
# 0
# 2
# 4
# 5
# Cov19
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov20
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov22
# 6
# Cov23
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
f_path = "HRV_features_BlockLevel.xlsx"
og_data = pd.read_excel(f_path, header=0)
og_data.head()
# Out:
#    Block SubjID  Fatigue_Rating  Unnamed: 3  HRV_MeanNN    HRV_SDNN  \
# 0      0   Cov4              73           0  754.876139  113.005049
# 1      1   Cov4              82           0  767.857143  118.329781
# 2      2   Cov4              82           0  755.166997  117.852649
# 3      3   Cov4              86           0  789.471419  136.276233
# 4      4   Cov4              84           0  768.864829  114.462897
#
#    HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  ...  HRV_SampEn  \
# 0   26.951449  104.236707    10.01841  111.349263  ...    1.741253
# 1   34.008529  111.348149         NaN         NaN  ...    1.861619
# 2   39.101073  111.234560         NaN         NaN  ...    1.872205
# 3   44.170195  125.032054         NaN         NaN  ...    1.910365
# 4   23.968917  112.300671         NaN         NaN  ...    1.723021
#
#    HRV_ShanEn  HRV_FuzzyEn  HRV_MSEn  HRV_CMSEn  HRV_RCMSEn    HRV_CD  \
# 0    4.681902     1.313249  1.426075   1.364724    1.996672  1.887790
# ...

# %%
copy = og_data
copy['Delta_fatigue'] = pd.Series()
copy['Change_from_Baseline'] = pd.Series()
# Out:
# <ipython-input-20-8e7495bb3953>:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   copy['Delta_fatigue'] = pd.Series()
# <ipython-input-20-8e7495bb3953>:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   copy['Change_from_Baseline'] = pd.Series()

# %%
candidates = og_data['SubjID'].unique()
for candidate in candidates:
  print(candidate)
  can_df = og_data.loc[og_data['SubjID'] == candidate]
  blocks = can_df['Block'].unique()
  prev = -1
  for block in blocks:
    print(block)
    block_df = can_df.loc[can_df['Block'] == block]
    fatigue_rating = block_df['Fatigue_Rating'].unique()[0]
    if block == 0:
      baseline = fatigue_rating
    if prev != -1:
      delta = fatigue_rating - prev
      baseline_shift = fatigue_rating - baseline
    else:
      delta = -1
      baseline_shift = -1
    prev = fatigue_rating
    mask = (copy['SubjID'] == candidate) & (copy['Block'] == block)
    copy.loc[mask, 'Delta_fatigue'] = delta
    copy.loc[mask, 'Change_from_Baseline'] = baseline_shift

copy.to_excel("HRV_features_BlockLevel_withDelta.xlsx")
# Out:
# Cov4
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov5
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov7
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov8
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov13
# 0
# 4
# 5
# 6
# Cov14
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov19
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov20
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov22
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Cov23
# 0
# 1
# 2
# 3
# 4
# 5
# 6
